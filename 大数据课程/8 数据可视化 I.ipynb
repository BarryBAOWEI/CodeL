# %% [markdown]
# <h1, align=center> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;数据科学引论 - Python之道 </h1>
#
# <h1, align=center> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;第8课 数据可视化 I - 美国人的死因分析</h1>

# %% [markdown]
# #### 目录
# 1. [美国人是怎么死的?死亡率之可视化](#top)
# 1. [matplotlib库](#mpl)
# 1. [获得数据](#getdata)
# 1. [理解数据](#understand)
# 1. [死亡: 年份](#year)
# 1. [死亡: 男性 vs. 女性](#gender)
# 1. [死亡: 年龄](#age)
# 1. [死亡: 年龄 & 性别](#ageXgender)
# 1. [死亡: 2015十大死因](#causeX2015)
# 1. [死亡: 每年十大死因](#causeXyear)
# 1. [死亡: 来自性别的死因](#causeXgender)
# 1. [死亡: 来自年龄的死因](#causeXage)
# 1. [死亡: 来自性别和年龄的死因](#causeXgenderXage)

# %% [markdown]
# # 美国人是怎么死的? 死亡率之可视化

# %% [markdown]
# **死亡** 一个可怕的主题，也是一个政府相当关心的主题。
#
# 在美国，疾病控制和预防中心（CDC）统计了一份从1999年至2015年的数据。这份数据信息量很丰富，包括死亡年龄、死因、性别甚至种族和地理城市。
#
# 对于这些数据，我们有下面三个问题 :
# - 美国最大的死因是什么?
# - 男人比女人更容易死吗? 死亡与年龄相关吗?
# - 随着时间的推移，哪些死因变得更加流行，哪些死因变得少见？

# %% [markdown]
# #### 学习数据可视化

# %% [markdown]
# **matplotlib**，python最流行的数据可视化包之一。
#
# 有很多不同方式去使用matplotlib，在此只介绍最基础的。如果你有兴趣，更多内容见文档[here](http://matplotlib.org/).

# %% [markdown]
# <a id="mpl"></a>
# ## 载入 `matplotlib` 库

# %%
import pandas as pd
import matplotlib.pyplot as plt
from imp import reload

#enable graphs to be displayed in notebooks
# %matplotlib inline 

#enable encoding of Chinese characters
import sys
reload(sys) 
#python2 sys.setdefaultencoding('GBK') #warning may display but is OK
# Out:
# <module 'sys' (built-in)>

# %% [markdown]
# <a id="getdata"></a>
# ## 获得数据

# %% [markdown]
# 从下面的链接中下载deaths.csv

# %%
#linux !wget --output-document /resources/data/deaths.csv https://ibm.box.com/shared/static/10iexjaa280qz4xcdtu98xlv51hqiybe.csv

# %% [markdown]
# 读取 `deaths.csv`文件内容:

# %%
#linux df = pd.read_csv("/resources/data/deaths.csv", encoding='GBK')
df = pd.read_csv("resources/data/deaths.csv", encoding='GBK')

# %% [markdown]
# 很好! 现在数据都在变量**`df`**内了

# %% [markdown]
# <a id="understand"></a>
# ## 理解数据

# %% [markdown]
# #### 前10行:

# %%
df.head(10)
# Out:
#                    Cause CauseCN Code-ICD-10-113  Age Gender  Year  Deaths  \
# 0  Salmonella infections  沙门氏菌感染       GR113-001    0      F  2005       0
# 1  Salmonella infections  沙门氏菌感染       GR113-001    0      F  2010       1
# 2  Salmonella infections  沙门氏菌感染       GR113-001    0      F  2015       3
# 3  Salmonella infections  沙门氏菌感染       GR113-001    1      F  2005       0
# 4  Salmonella infections  沙门氏菌感染       GR113-001    1      F  2010       0
# 5  Salmonella infections  沙门氏菌感染       GR113-001    1      F  2015       0
# 6  Salmonella infections  沙门氏菌感染       GR113-001    2      F  2005       0
# 7  Salmonella infections  沙门氏菌感染       GR113-001    2      F  2010       0
# 8  Salmonella infections  沙门氏菌感染       GR113-001    2      F  2015       0
# 9  Salmonella infections  沙门氏菌感染       GR113-001    3      F  2005       0
#
#   Population  Crude Rate
# 0    1956682  Unreliable
# 1    1929877  Unreliable
# 2    1942904  Unreliable
# 3    1950494  Unreliable
# 4    1947217  Unreliable
# 5    1939269  Unreliable
# 6    1932337  Unreliable
# 7    2004731  Unreliable
# 8    1939979  Unreliable
# 9    1930395  Unreliable

# %% [markdown]
# #### 倒数5行:

# %%
df.tail(5)
# Out:
#                                             Cause         CauseCN  \
# 30901  Enterocolitis due to Clostridium difficile  由于艰难梭菌引起的小肠结肠炎
# 30902  Enterocolitis due to Clostridium difficile  由于艰难梭菌引起的小肠结肠炎
# 30903  Enterocolitis due to Clostridium difficile  由于艰难梭菌引起的小肠结肠炎
# 30904  Enterocolitis due to Clostridium difficile  由于艰难梭菌引起的小肠结肠炎
# 30905  Enterocolitis due to Clostridium difficile  由于艰难梭菌引起的小肠结肠炎
#
#       Code-ICD-10-113  Age Gender  Year  Deaths      Population  \
# 30901       GR113-136   99      M  2010       6  Not Applicable
# 30902       GR113-136   99      M  2015       7  Not Applicable
# 30903       GR113-136  100      M  2005       8  Not Applicable
# 30904       GR113-136  100      M  2010       4  Not Applicable
# 30905       GR113-136  100      M  2015      14  Not Applicable
#
#            Crude Rate
# 30901  Not Applicable
# 30902  Not Applicable
# 30903  Not Applicable
# 30904  Not Applicable
# 30905  Not Applicable

# %% [markdown]
# #### 死亡年龄的汇总情况

# %%
df.Age.describe()
# Out:
# count    30906.000000
# mean        50.000000
# std         29.155231
# min          0.000000
# 25%         25.000000
# 50%         50.000000
# 75%         75.000000
# max        100.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### 数据集涉及了哪几个年份?

# %%
df.Year.unique()
# Out:
# array([2005, 2010, 2015])

# %% [markdown]
# #### 确认性别是否只有男性male和女性female。

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# #### 死亡人数汇总?

# %%
df.Deaths.describe()
# Out:
# count    30906.000000
# mean       211.636511
# std        930.959087
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%         41.000000
# max      13846.000000
# Name: Deaths, dtype: float64

# %% [markdown]
# #### 数据集中有哪些死因?

# %%
causes = df[['Cause', 'CauseCN']].drop_duplicates(subset = ['Cause','CauseCN']) #remove duplicates
causes = causes.sort_values(['Cause']) #sort
causes.index=range(0, len(causes)) #re-index the row numbers
causes
# Out:
#                                                 Cause                CauseCN
# 0                  Accidents (unintentional injuries)               事故（意外伤害）
# 1                  Acute bronchitis and bronchiolitis           急性支气管炎和细支气管炎
# 2                                 Acute poliomyelitis                急性脊髓灰质炎
# 3                                 Alzheimer's disease                阿尔茨海默氏病
# 4                                             Anemias                     贫血
# 5                      Aortic aneurysm and dissection                主动脉瘤和解剖
# 6                  Arthropod-borne viral encephalitis           节肢动物传播的病毒性脑炎
# 7                                  Assault (homicide)                 袭击（杀人）
# 8                                     Atherosclerosis                 动脉粥样硬化
# 9                            Cerebrovascular diseases                  脑血管疾病
# 10  Certain conditions originating in the perinata...               围产期的某些病症
# 11  Cholelithiasis and other disorders of gallbladder             胆石症和其他胆囊疾病
# 12                Chronic liver disease and cirrhosis               慢性肝病和肝硬化
# 13                 Chronic lower respiratory diseases               慢性下呼吸道疾病
# 14         Complications of medical and surgical care            医疗和外科护理的并发症
# 15  Congenital malformations, deformations and chr...         先天性畸形，变形和染色体异常
# 16                                  Diabetes mellitus                    糖尿病
# 17                               Diseases of appendix                    阑尾病
# 18                                  Diseases of heart                    心脏病
# 19         Enterocolitis due to Clostridium difficile         由于艰难梭菌引起的小肠结肠炎
# 20  Essential hypertension and hypertensive renal ...          原发性高血压和高血压性肾病
# 21                                        HIV disease                   艾滋病毒
# 22                                             Hernia                      疝
# 23                            Hyperplasia of prostate                  前列腺增生
# 24  In situ neoplasms, benign neoplasms and neopla...  原位肿瘤，良性肿瘤和不确定或未知行为的肿瘤
# 25                               Infections of kidney                   肾脏感染
# 26      Inflammatory diseases of female pelvic organs            女性盆腔器官炎症性疾病
# 27                            Influenza and pneumonia                  流感和肺炎
# 28                    Intentional self-harm (suicide)               故意自伤（自杀）
# 29                                 Legal intervention                   法律干预
# 30                                            Malaria                     疟疾
# 31                                Malignant neoplasms                   恶性肿瘤
# 32                                            Measles                     麻疹
# 33                                         Meningitis                    脑膜炎
# 34                            Meningococcal infection                脑膜炎球菌感染
# 35        Nephritis, nephrotic syndrome and nephrosis            肾炎，肾病综合征和肾病
# 36                           Nutritional deficiencies                   营养缺乏
# 37               Operations of war and their sequelae             战争的行动及其后遗症
# 38                                Parkinson's disease                   帕金森病
# 39                                       Peptic ulcer                  消化性溃疡
# 40                Pneumoconioses and chemical effects                肺炎和化学效应
# 41              Pneumonitis due to solids and liquids             由于固体和液体的肺炎
# 42           Pregnancy, childbirth and the puerperium               怀孕，分娩和产褥
# 43                              Salmonella infections                 沙门氏菌感染
# 44                       Scarlet fever and erysipelas                 猩红热和丹毒
# 45                                         Septicemia                    败血症
# 46                          Shigellosis and amebiasis           志贺杆菌性痢疾和阿米巴病
# 47                                           Syphilis                     梅毒
# 48                                       Tuberculosis                     结核
# 49                                    Viral hepatitis                  病毒性肝炎
# 50                                     Whooping cough                    百日咳

# %% [markdown]
# <a id="year"></a>
# ## 死亡: 年份

# %% [markdown]
# #### 再看看数据:

# %%
df.head(3)
# Out:
#                    Cause CauseCN Code-ICD-10-113  Age Gender  Year  Deaths  \
# 0  Salmonella infections  沙门氏菌感染       GR113-001    0      F  2005       0
# 1  Salmonella infections  沙门氏菌感染       GR113-001    0      F  2010       1
# 2  Salmonella infections  沙门氏菌感染       GR113-001    0      F  2015       3
#
#   Population  Crude Rate
# 0    1956682  Unreliable
# 1    1929877  Unreliable
# 2    1942904  Unreliable

# %% [markdown]
# ####  2005, 2010，2015死亡人数分别为多少?

# %% [markdown]
# 我们先按照年份进行分组，然后对**死亡数**列求和，就可以得到每年的死亡数

# %%
by_year = df.groupby("Year").Deaths.sum()
by_year
# Out:
# Year
# 2005    2143662
# 2010    2102234
# 2015    2294942
# Name: Deaths, dtype: int64

# %% [markdown]
# 使用 **`.plot()`**画图

# %%
by_year.plot(kind = "bar")

# %% [markdown]
# #### 我们可以用一句话重写上述过程，这样看起来更加简洁。

# %%
# Making syntax easier to read. \ tells Python to continue to the next line before executing 
df.groupby("Year")\
.Deaths\
.sum()\
.plot(kind = "bar")

# %% [markdown]
# <a id="gender"></a>
# ## 死亡: 男性 vs. 女性

# %% [markdown]
# 在2015年，哪个性别死亡率更高？

# %%
df2015 = df[df.Year == 2015]

df2015\
.groupby("Gender")\
.Deaths\
.sum()
# Out:
# Gender
# F    1103789
# M    1191153
# Name: Deaths, dtype: int64

# %% [markdown]
# #### <font color="red"> 练习: </font>你可以创建一个简单的图来表示每个性别的死亡总数吗?
#
# 注意，使用2015年的数据。

# %%
## HIDE AS SOLUTION:
df2015\
.groupby("Gender")\
.Deaths\
.sum()\
.plot(kind = "bar")

# %% [markdown]
# 让我们给图上色: <font color=red>红色</font>表示女性<font color=blue>蓝色</font>表示男性.
# 我们可以这样添加颜色：
# > `.plot(kind = "bar", ` **`color = ["red", "blue"]`**`)`

# %%
df2015\
.groupby("Gender")\
.Deaths\
.sum()\
.plot(kind = "bar", color = ["red", "blue"])

# %% [markdown]
# <a id="age"></a>
# ## 死亡: 年龄

# %% [markdown]
# 2015年死亡人员的年龄情况？

# %%
df2015\
.groupby("Age")\
.Deaths\
.sum()\
.plot(kind = "bar", color = "grey")

# %% [markdown]
# 上面这张图比较难观察，太小了！
#
# 我们可以增大图的尺寸
# > `.plot(kind = "bar",`** figsize = [18,6]**`)`

# %%
df2015\
.groupby("Age")\
.Deaths\
.sum()\
.plot(kind = "bar", color = "grey", figsize = [18,6])

# %% [markdown]
# <font color="green"> 讨论: 你从图中发现了什么? </font>

# %% [markdown]
# <a id="ageXgender"></a>
# ## 死亡: 年龄和性别

# %% [markdown]
# #### 死亡年龄与性别有关吗？

# %% [markdown]
# 根据两个变量进行分组：
# > `.groupby(`**`["Age", "Gender"]`**`)`

# %%
df2015\
.groupby(["Age", "Gender"])\
.Deaths\
.sum()
# Out:
# Age  Gender
# 0    F          8634
#      M         10512
# 1    F           470
#      M           645
# 2    F           335
#      M           448
# 3    F           239
#      M           372
# 4    F           191
#      M           280
# 5    F           185
#      M           252
# 6    F           197
#      M           215
# 7    F           168
#      M           191
# 8    F           149
#      M           206
# 9    F           143
#      M           215
# 10   F           117
#      M           209
# 11   F           147
#      M           207
# 12   F           166
#      M           240
# 13   F           230
#      M           311
# 14   F           282
#      M           454
#                ...
# 86   F         34950
#      M         29452
# 87   F         36181
#      M         29581
# 88   F         36741
#      M         27971
# 89   F         36253
#      M         25708
# 90   F         36327
#      M         23963
# 91   F         34454
#      M         21538
# 92   F         31655
#      M         18526
# 93   F         29469
#      M         16069
# 94   F         25504
#      M         13110
# 95   F         21470
#      M         10068
# 96   F         16610
#      M          7096
# 97   F         13788
#      M          5334
# 98   F         10558
#      M          3669
# 99   F          7685
#      M          2506
# 100  F         16615
#      M          3985
# Name: Deaths, dtype: int64

# %% [markdown]
# #### 让我们创建两个子图，分别是女性和男性的死亡年龄。
# > ...
# > **`.unstack(1)`**`\`
# > `.plot(kind = "bar", ` **` subplots = True`**`)`

# %%
df2015\
.groupby(["Age", "Gender"])\
.Deaths\
.sum()\
.unstack(1)\
.plot(kind = "bar", color = ["red","blue"], figsize = [18,10], subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x114d86a20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11546b518>], dtype=object)

# %% [markdown]
# <font color="green"> 讨论: 从图中你发现了什么? </font>

# %% [markdown]
# 我们可以把男性和女性的数据堆在一张图里：
# >`.plot(kind = "bar", ` **`stacked = True`**`)`

# %%
df2015\
.groupby(["Age", "Gender"])\
.Deaths\
.sum()\
.unstack(1)\
.plot(kind = "bar", color = ["red","blue"], figsize = [18,10], stacked = True)

# %% [markdown]
# 但是这并不能很好地对比两个性别的差距。

# %% [markdown]
# #### 因为年龄是数值变量，所以使用折线图可能更加容易对比:
# > `.plot(kind = "`**`line`**`")`

# %%
df2015\
.groupby(["Age", "Gender"])\
.Deaths\
.sum()\
.unstack(1)\
.plot(kind = "line", figsize = [18,10], subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11605b2e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116422898>], dtype=object)

# %% [markdown]
# 有了曲线之后，对比变得方便了，我们要把两根线同时绘制到一张图:
# >`...`
# >**`.unstack(1)`**`\`
# >`.plot(kind = "line")   #Default: subplots = False`

# %%
df2015\
.groupby(["Age", "Gender"])\
.Deaths\
.sum()\
.unstack(1)\
.plot(kind = "line", color = ["red","blue"], figsize = [18,6])

# %% [markdown]
# 让我们增加一个题目和y坐标的名称。
#
# > `.plot(kind = "line",` **`title = "Deaths in 2015 by Age and Gender"`**`)`

# %%
df2015\
.groupby(["Age", "Gender"])\
.Deaths\
.sum()\
.unstack(1)\
.plot(kind = "line", color = ["red","blue"], figsize = [10,6], title = "Deaths in 2015 by Age and Gender")

# %% [markdown]
# <a id="causeX2015"></a>
# ## 死亡: 2015年最大死因

# %% [markdown]
# 让我们查看一下2015年最大的死因。

# %%
df2015\
.groupby(["Cause"])\
.Deaths\
.sum()\
.plot(kind = "bar", color = "black")

# %% [markdown]
# 这张图观察起来非常困难，我们需要先对数据**排序**，然后将图表**旋转90度**。
# 1. 数据排序:
# > **`.sort('Deaths', ascending = True)`**
#
# 2. 创建水平柱状图
# > **`.plot(kind = "barh")`**

# %%
df2015\
.groupby(["Cause"])\
.agg({'Deaths' : sum})\
.sort_values('Deaths', ascending = True)\
.plot(kind = "barh", legend = False, color = "black", figsize = [10,8])

# %% [markdown]
# #### 让我们找出2015年十大死因
#
# 我们可以在排序后取最后的10个死因:
# >`.sort('Deaths', ascending = True)`**`[-10:]`**`\`

# %%
df2015\
.groupby(["Cause"])\
.agg({'Deaths' : sum})\
.sort_values('Deaths')[-10:]\
.plot(kind = "barh", legend = False, color = "black", figsize = [10,8], title = "2015 Top 10 Causes of Death in USA")

# %% [markdown]
# <a id="causeXyear"></a>
# ## 死亡: 每年的最大死因

# %%
df\
.groupby(["Cause","Year"])\
.agg({'Deaths' : sum})\
.sort_values('Deaths', ascending = False)\
.unstack(1)\
.plot(kind = "barh", legend = True, figsize = [10,24])

# %% [markdown]
# 这张图内容太多，有很多信息并不直观，例如，你注意到HIV的死亡率在2005年后逐渐走低了吗？

# %% [markdown]
# <a id="causeXgender"></a>
# ## 死亡: 跟性别有关的死因

# %%
df2015\
.sort_values('Deaths', ascending = False)\
.groupby(["Cause","Gender"])\
.agg({'Deaths' : sum})\
.unstack(1)\
.plot(kind = "barh", color = ["red", "blue"], legend = True, figsize = [10,24])

# %% [markdown]
# <a id="causeXage"></a>
# ## 死亡: 跟年龄有关的死因

# %% [markdown]
# 因为这里死因太多了，年龄也多，交叉在一起图表会非常地大，所以我们只选择其中一些死因来可视化：
#
# - "Alzheimer's disease"
# - "Diseases of heart"
# - "Malignant neoplasms"
# - "Accidents (unintentional injuries)"

# %%
clist = ["Alzheimer's disease", 
         "Diseases of heart", 
         "Malignant neoplasms", 
         "Accidents (unintentional injuries)"]

df2015_clist = df2015[df2015["Cause"].isin(clist)]

df2015_clist\
.groupby(["Age","Cause"])\
.agg({'Deaths' : sum})\
.sort_values('Deaths', ascending = False)\
.unstack(1)\
.plot(kind = "line", legend = True, figsize = [10,6])

# %% [markdown]
# <a id="causeXgenderXage"></a>
# ## 死亡: 死因与性别、年龄的关系

# %% [markdown]
# 对两个性别、三个年份、51种死因的交叉可视化是十分苦难的。因为内容太多，难以放入一张图中。
# 最好的做法是选择性地展示一些有意义的数据。

# %%
clist = df.Cause.unique()

for cause in clist:
    df2015_clist = df2015[df2015["Cause"].isin([cause])]
    
    df2015_clist\
    .groupby(["Age","Gender"])\
    .agg({'Deaths' : sum})\
    .unstack([1])\
    .plot(kind = "line", legend = True, color=('r','b'), figsize = [10,8], title = str(cause))
# Out:
# /Users/chenhaopeng/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# <hr>

# %% [markdown]
# <font color="green"> 讨论: 上述图中你们发现了什么? </font>
